# %% [markdown]
# <a href="https://colab.research.google.com/github/RamyaNuvvala/demo/blob/main/nyc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
#importing the dataset
dataset=pd.read_csv("/content/311_Service_Requests_from_2010_to_Present.csv.crdownload")
pd.options.display.max_columns = None
dataset.head(4)
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    15790200  01/23/2010 07:32:50 PM  01/23/2010 07:59:54 PM   NYPD
# 1    15790201  01/23/2010 07:49:13 PM  01/23/2010 08:49:01 PM   NYPD
# 2    15790202  01/23/2010 10:09:17 PM  04/28/2010 02:56:43 PM    DOE
# 3    15790203  01/23/2010 10:55:44 PM  01/23/2010 11:15:53 PM   NYPD
#
#                          Agency Name       Complaint Type  \
# 0    New York City Police Department  Noise - Residential
# 1    New York City Police Department  Noise - Residential
# 2  Central - Department of Education               Safety
# 3    New York City Police Department  Noise - Residential
#
#                Descriptor               Location Type  Incident Zip  \
# 0        Loud Music/Party  Residential Building/House       11206.0
# 1        Loud Music/Party  Residential Building/House       11691.0
# 2  Student Being Harassed                      School       11217.0
# 3        Banging/Pounding  Residential Building/House       10454.0
#
#        Incident Address      Street Name   Cross Street 1  \
# 0   199 MESEROLE STREET  MESEROLE STREET  HUMBOLDT STREET
# 1  15-30 HASSOCK STREET   HASSOCK STREET   REDFERN AVENUE
# 2         62 PARK PLACE       PARK PLACE         6 AVENUE
# 3      370 BROOK AVENUE     BROOK AVENUE  EAST 142 STREET
#
#         Cross Street 2 Intersection Street 1 Intersection Street 2  \
# 0      BUSHWICK AVENUE                   NaN                   NaN
# 1  BEACH CHANNEL DRIVE                   NaN                   NaN
# 2             5 AVENUE                   NaN                   NaN
# 3      EAST 143 STREET                   NaN                   NaN
#
#   Address Type          City Landmark    Facility Type  Status  \
# 0      ADDRESS      BROOKLYN      NaN         Precinct  Closed
# 1      ADDRESS  FAR ROCKAWAY      NaN         Precinct  Closed
# 2          NaN      BROOKLYN      NaN  School District  Closed
# 3      ADDRESS         BRONX      NaN         Precinct  Closed
#
#                  Due Date                             Resolution Description  \
# 0  01/24/2010 03:32:50 AM  The Police Department responded to the complai...
# 1  01/24/2010 03:49:13 AM  The Police Department responded to the complai...
# 2  01/27/2010 10:09:17 PM  The Department of Education is reviewing your ...
# 3  01/24/2010 06:55:44 AM  The Police Department responded to the complai...
#
#   Resolution Action Updated Date Community Board           BBL   Borough  \
# 0         01/23/2010 07:59:55 PM     01 BROOKLYN  3.030450e+09  BROOKLYN
# 1         01/23/2010 08:49:01 PM       14 QUEENS  4.155010e+09    QUEENS
# 2         04/28/2010 02:56:43 PM     06 BROOKLYN  3.009410e+09  BROOKLYN
# 3         01/23/2010 11:15:53 PM        01 BRONX  2.022690e+09     BRONX
#
#    X Coordinate (State Plane)  Y Coordinate (State Plane)  \
# 0                   1000663.0                    197341.0
# 1                   1052873.0                    161058.0
# 2                    990769.0                    186649.0
# 3                   1007114.0                    234638.0
#
#   Open Data Channel Type Park Facility Name Park Borough Vehicle Type  \
# 0                  PHONE        Unspecified     BROOKLYN          NaN
# 1                  PHONE        Unspecified       QUEENS          NaN
# 2                  PHONE     School - PS 77     BROOKLYN          NaN
# 3                  PHONE        Unspecified        BRONX          NaN
#
#   Taxi Company Borough Taxi Pick Up Location Bridge Highway Name  \
# 0                  NaN                   NaN                 NaN
# 1                  NaN                   NaN                 NaN
# 2                  NaN                   NaN                 NaN
# 3                  NaN                   NaN                 NaN
#
#   Bridge Highway Direction Road Ramp Bridge Highway Segment   Latitude  \
# 0                      NaN       NaN                    NaN  40.708317
# 1                      NaN       NaN                    NaN  40.608478
# 2                      NaN       NaN                    NaN  40.678983
# 3                      NaN       NaN                    NaN  40.810673
#
#    Longitude                                  Location
# 0 -73.940800  (40.708316992485734, -73.94079991324266)
# 1 -73.752853     (40.6084776535044, -73.7528533996258)
# 2 -73.976497  (40.678982749894104, -73.97649694847125)
# 3 -73.917405   (40.81067332885121, -73.91740495406697)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10569 entries, 0 to 10568
# Data columns (total 41 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unique Key                      10569 non-null  int64
#  1   Created Date                    10569 non-null  object
#  2   Closed Date                     10224 non-null  object
#  3   Agency                          10569 non-null  object
#  4   Agency Name                     10569 non-null  object
#  5   Complaint Type                  10569 non-null  object
#  6   Descriptor                      10540 non-null  object
#  7   Location Type                   9163 non-null   object
#  8   Incident Zip                    10120 non-null  float64
#  9   Incident Address                8628 non-null   object
#  10  Street Name                     8626 non-null   object
#  11  Cross Street 1                  8800 non-null   object
#  12  Cross Street 2                  8789 non-null   object
#  13  Intersection Street 1           983 non-null    object
#  14  Intersection Street 2           983 non-null    object
#  15  Address Type                    10178 non-null  object
#  16  City                            10126 non-null  object
#  17  Landmark                        11 non-null     object
#  18  Facility Type                   1816 non-null   object
#  19  Status                          10569 non-null  object
#  20  Due Date                        3823 non-null   object
#  21  Resolution Description          10565 non-null  object
#  22  Resolution Action Updated Date  10488 non-null  object
#  23  Community Board                 10567 non-null  object
#  24  BBL                             8329 non-null   float64
#  25  Borough                         10567 non-null  object
#  26  X Coordinate (State Plane)      9475 non-null   float64
#  27  Y Coordinate (State Plane)      9475 non-null   float64
#  28  Open Data Channel Type          10568 non-null  object
#  29  Park Facility Name              10568 non-null  object
#  30  Park Borough                    10567 non-null  object
#  31  Vehicle Type                    7 non-null      object
#  32  Taxi Company Borough            9 non-null      object
#  33  Taxi Pick Up Location           110 non-null    object
#  34  Bridge Highway Name             32 non-null     object
#  35  Bridge Highway Direction        32 non-null     object
#  36  Road Ramp                       31 non-null     object
#  37  Bridge Highway Segment          31 non-null     object
#  38  Latitude                        9475 non-null   float64
#  39  Longitude                       9475 non-null   float64
#  40  Location                        9475 non-null   object
# dtypes: float64(6), int64(1), object(34)
# memory usage: 3.3+ MB

# %%
dataset.dtypes
# Out:
# Unique Key                                 int64
# Created Date                      datetime64[ns]
# Closed Date                       datetime64[ns]
# Agency                                    object
# Agency Name                               object
# Complaint Type                            object
# Descriptor                                object
# Location Type                             object
# Incident Zip                             float64
# Incident Address                          object
# Street Name                               object
# Cross Street 1                            object
# Cross Street 2                            object
# Intersection Street 1                     object
# Intersection Street 2                     object
# Address Type                              object
# City                                      object
# Landmark                                  object
# Facility Type                             object
# Status                                    object
# Due Date                                  object
# Resolution Description                    object
# Resolution Action Updated Date            object
# Community Board                           object
# BBL                                      float64
# Borough                                   object
# X Coordinate (State Plane)               float64
# Y Coordinate (State Plane)               float64
# Open Data Channel Type                    object
# Park Facility Name                        object
# Park Borough                              object
# Vehicle Type                              object
# Taxi Company Borough                      object
# Taxi Pick Up Location                     object
# Bridge Highway Name                       object
# Bridge Highway Direction                  object
# Road Ramp                                 object
# Bridge Highway Segment                    object
# Latitude                                 float64
# Longitude                                float64
# Location                                  object
# dtype: object

# %%
dataset['Created Date']=pd.to_datetime(dataset['Created Date'])
dataset['Closed Date']=pd.to_datetime(dataset['Closed Date'])

# %%
dataset.head(5)
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    15790200 2010-01-23 19:32:50 2010-01-23 19:59:54   NYPD
# 1    15790201 2010-01-23 19:49:13 2010-01-23 20:49:01   NYPD
# 2    15790202 2010-01-23 22:09:17 2010-04-28 14:56:43    DOE
# 3    15790203 2010-01-23 22:55:44 2010-01-23 23:15:53   NYPD
# 4    15790204 2010-01-23 11:55:47 2010-02-10 11:51:00  DOHMH
#
#                                Agency Name       Complaint Type  \
# 0          New York City Police Department  Noise - Residential
# 1          New York City Police Department  Noise - Residential
# 2        Central - Department of Education               Safety
# 3          New York City Police Department  Noise - Residential
# 4  Department of Health and Mental Hygiene        Unleashed Dog
#
#                 Descriptor               Location Type  Incident Zip  \
# 0         Loud Music/Party  Residential Building/House       11206.0
# 1         Loud Music/Party  Residential Building/House       11691.0
# 2   Student Being Harassed                      School       11217.0
# 3         Banging/Pounding  Residential Building/House       10454.0
# 4  Unleashed Dog in Public        Public/Unfenced Area       11436.0
#
#        Incident Address      Street Name   Cross Street 1  \
# 0   199 MESEROLE STREET  MESEROLE STREET  HUMBOLDT STREET
# 1  15-30 HASSOCK STREET   HASSOCK STREET   REDFERN AVENUE
# 2         62 PARK PLACE       PARK PLACE         6 AVENUE
# 3      370 BROOK AVENUE     BROOK AVENUE  EAST 142 STREET
# 4     142-52 122 AVENUE       122 AVENUE         DEAD END
#
#         Cross Street 2 Intersection Street 1 Intersection Street 2  \
# 0      BUSHWICK AVENUE                   NaN                   NaN
# 1  BEACH CHANNEL DRIVE                   NaN                   NaN
# 2             5 AVENUE                   NaN                   NaN
# 3      EAST 143 STREET                   NaN                   NaN
# 4           143 STREET                   NaN                   NaN
#
#   Address Type          City Landmark    Facility Type  Status  \
# 0      ADDRESS      BROOKLYN      NaN         Precinct  Closed
# 1      ADDRESS  FAR ROCKAWAY      NaN         Precinct  Closed
# 2          NaN      BROOKLYN      NaN  School District  Closed
# 3      ADDRESS         BRONX      NaN         Precinct  Closed
# 4      ADDRESS       JAMAICA      NaN              NaN  Closed
#
#                  Due Date                             Resolution Description  \
# 0  01/24/2010 03:32:50 AM  The Police Department responded to the complai...
# 1  01/24/2010 03:49:13 AM  The Police Department responded to the complai...
# 2  01/27/2010 10:09:17 PM  The Department of Education is reviewing your ...
# 3  01/24/2010 06:55:44 AM  The Police Department responded to the complai...
# 4  02/22/2010 11:55:47 AM  The Department of Health and Mental Hygiene ha...
#
#   Resolution Action Updated Date Community Board           BBL   Borough  \
# 0         01/23/2010 07:59:55 PM     01 BROOKLYN  3.030450e+09  BROOKLYN
# 1         01/23/2010 08:49:01 PM       14 QUEENS  4.155010e+09    QUEENS
# 2         04/28/2010 02:56:43 PM     06 BROOKLYN  3.009410e+09  BROOKLYN
# 3         01/23/2010 11:15:53 PM        01 BRONX  2.022690e+09     BRONX
# 4         02/10/2010 11:51:00 AM       12 QUEENS  4.120380e+09    QUEENS
#
#    X Coordinate (State Plane)  Y Coordinate (State Plane)  \
# 0                   1000663.0                    197341.0
# 1                   1052873.0                    161058.0
# 2                    990769.0                    186649.0
# 3                   1007114.0                    234638.0
# 4                   1040656.0                    185333.0
#
#   Open Data Channel Type Park Facility Name Park Borough Vehicle Type  \
# 0                  PHONE        Unspecified     BROOKLYN          NaN
# 1                  PHONE        Unspecified       QUEENS          NaN
# 2                  PHONE     School - PS 77     BROOKLYN          NaN
# 3                  PHONE        Unspecified        BRONX          NaN
# 4                  PHONE        Unspecified       QUEENS          NaN
#
#   Taxi Company Borough Taxi Pick Up Location Bridge Highway Name  \
# 0                  NaN                   NaN                 NaN
# 1                  NaN                   NaN                 NaN
# 2                  NaN                   NaN                 NaN
# 3                  NaN                   NaN                 NaN
# 4                  NaN                   NaN                 NaN
#
#   Bridge Highway Direction Road Ramp Bridge Highway Segment   Latitude  \
# 0                      NaN       NaN                    NaN  40.708317
# 1                      NaN       NaN                    NaN  40.608478
# 2                      NaN       NaN                    NaN  40.678983
# 3                      NaN       NaN                    NaN  40.810673
# 4                      NaN       NaN                    NaN  40.675193
#
#    Longitude                                  Location
# 0 -73.940800  (40.708316992485734, -73.94079991324266)
# 1 -73.752853     (40.6084776535044, -73.7528533996258)
# 2 -73.976497  (40.678982749894104, -73.97649694847125)
# 3 -73.917405   (40.81067332885121, -73.91740495406697)
# 4 -73.796650  (40.675193324229525, -73.79664995040157)

# %%
dataset['Request_Closing_Time'] = dataset['Closed Date']-dataset['Created Date']

# %%
dataset.head(5)
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    15790200 2010-01-23 19:32:50 2010-01-23 19:59:54   NYPD
# 1    15790201 2010-01-23 19:49:13 2010-01-23 20:49:01   NYPD
# 2    15790202 2010-01-23 22:09:17 2010-04-28 14:56:43    DOE
# 3    15790203 2010-01-23 22:55:44 2010-01-23 23:15:53   NYPD
# 4    15790204 2010-01-23 11:55:47 2010-02-10 11:51:00  DOHMH
#
#                                Agency Name       Complaint Type  \
# 0          New York City Police Department  Noise - Residential
# 1          New York City Police Department  Noise - Residential
# 2        Central - Department of Education               Safety
# 3          New York City Police Department  Noise - Residential
# 4  Department of Health and Mental Hygiene        Unleashed Dog
#
#                 Descriptor               Location Type  Incident Zip  \
# 0         Loud Music/Party  Residential Building/House       11206.0
# 1         Loud Music/Party  Residential Building/House       11691.0
# 2   Student Being Harassed                      School       11217.0
# 3         Banging/Pounding  Residential Building/House       10454.0
# 4  Unleashed Dog in Public        Public/Unfenced Area       11436.0
#
#        Incident Address      Street Name   Cross Street 1  \
# 0   199 MESEROLE STREET  MESEROLE STREET  HUMBOLDT STREET
# 1  15-30 HASSOCK STREET   HASSOCK STREET   REDFERN AVENUE
# 2         62 PARK PLACE       PARK PLACE         6 AVENUE
# 3      370 BROOK AVENUE     BROOK AVENUE  EAST 142 STREET
# 4     142-52 122 AVENUE       122 AVENUE         DEAD END
#
#         Cross Street 2 Intersection Street 1 Intersection Street 2  \
# 0      BUSHWICK AVENUE                   NaN                   NaN
# 1  BEACH CHANNEL DRIVE                   NaN                   NaN
# 2             5 AVENUE                   NaN                   NaN
# 3      EAST 143 STREET                   NaN                   NaN
# 4           143 STREET                   NaN                   NaN
#
#   Address Type          City Landmark    Facility Type  Status  \
# 0      ADDRESS      BROOKLYN      NaN         Precinct  Closed
# 1      ADDRESS  FAR ROCKAWAY      NaN         Precinct  Closed
# 2          NaN      BROOKLYN      NaN  School District  Closed
# 3      ADDRESS         BRONX      NaN         Precinct  Closed
# 4      ADDRESS       JAMAICA      NaN              NaN  Closed
#
#                  Due Date                             Resolution Description  \
# 0  01/24/2010 03:32:50 AM  The Police Department responded to the complai...
# 1  01/24/2010 03:49:13 AM  The Police Department responded to the complai...
# 2  01/27/2010 10:09:17 PM  The Department of Education is reviewing your ...
# 3  01/24/2010 06:55:44 AM  The Police Department responded to the complai...
# 4  02/22/2010 11:55:47 AM  The Department of Health and Mental Hygiene ha...
#
#   Resolution Action Updated Date Community Board           BBL   Borough  \
# 0         01/23/2010 07:59:55 PM     01 BROOKLYN  3.030450e+09  BROOKLYN
# 1         01/23/2010 08:49:01 PM       14 QUEENS  4.155010e+09    QUEENS
# 2         04/28/2010 02:56:43 PM     06 BROOKLYN  3.009410e+09  BROOKLYN
# 3         01/23/2010 11:15:53 PM        01 BRONX  2.022690e+09     BRONX
# 4         02/10/2010 11:51:00 AM       12 QUEENS  4.120380e+09    QUEENS
#
#    X Coordinate (State Plane)  Y Coordinate (State Plane)  \
# 0                   1000663.0                    197341.0
# 1                   1052873.0                    161058.0
# 2                    990769.0                    186649.0
# 3                   1007114.0                    234638.0
# 4                   1040656.0                    185333.0
#
#   Open Data Channel Type Park Facility Name Park Borough Vehicle Type  \
# 0                  PHONE        Unspecified     BROOKLYN          NaN
# 1                  PHONE        Unspecified       QUEENS          NaN
# 2                  PHONE     School - PS 77     BROOKLYN          NaN
# 3                  PHONE        Unspecified        BRONX          NaN
# 4                  PHONE        Unspecified       QUEENS          NaN
#
#   Taxi Company Borough Taxi Pick Up Location Bridge Highway Name  \
# 0                  NaN                   NaN                 NaN
# 1                  NaN                   NaN                 NaN
# 2                  NaN                   NaN                 NaN
# 3                  NaN                   NaN                 NaN
# 4                  NaN                   NaN                 NaN
#
#   Bridge Highway Direction Road Ramp Bridge Highway Segment   Latitude  \
# 0                      NaN       NaN                    NaN  40.708317
# 1                      NaN       NaN                    NaN  40.608478
# 2                      NaN       NaN                    NaN  40.678983
# 3                      NaN       NaN                    NaN  40.810673
# 4                      NaN       NaN                    NaN  40.675193
#
#    Longitude                                  Location Request_Closing_Time
# 0 -73.940800  (40.708316992485734, -73.94079991324266)      0 days 00:27:04
# 1 -73.752853     (40.6084776535044, -73.7528533996258)      0 days 00:59:48
# 2 -73.976497  (40.678982749894104, -73.97649694847125)     94 days 16:47:26
# 3 -73.917405   (40.81067332885121, -73.91740495406697)      0 days 00:20:09
# 4 -73.796650  (40.675193324229525, -73.79664995040157)     17 days 23:55:13

# %%
dataset.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Description', 'Resolution Action Updated Date',
#        'Community Board', 'BBL', 'Borough', 'X Coordinate (State Plane)',
#        'Y Coordinate (State Plane)', 'Open Data Channel Type',
#        'Park Facility Name', 'Park Borough', 'Vehicle Type',
#        'Taxi Company Borough', 'Taxi Pick Up Location', 'Bridge Highway Name',
#        'Bridge Highway Direction', 'Road Ramp', 'Bridge Highway Segment',
#        'Latitude', 'Longitude', 'Location', 'Request_Closing_Time'],
#       dtype='object')

# %%
dataset.head()
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    15790200 2010-01-23 19:32:50 2010-01-23 19:59:54   NYPD
# 1    15790201 2010-01-23 19:49:13 2010-01-23 20:49:01   NYPD
# 2    15790202 2010-01-23 22:09:17 2010-04-28 14:56:43    DOE
# 3    15790203 2010-01-23 22:55:44 2010-01-23 23:15:53   NYPD
# 4    15790204 2010-01-23 11:55:47 2010-02-10 11:51:00  DOHMH
#
#                                Agency Name       Complaint Type  \
# 0          New York City Police Department  Noise - Residential
# 1          New York City Police Department  Noise - Residential
# 2        Central - Department of Education               Safety
# 3          New York City Police Department  Noise - Residential
# 4  Department of Health and Mental Hygiene        Unleashed Dog
#
#                 Descriptor               Location Type  Incident Zip  \
# 0         Loud Music/Party  Residential Building/House       11206.0
# 1         Loud Music/Party  Residential Building/House       11691.0
# 2   Student Being Harassed                      School       11217.0
# 3         Banging/Pounding  Residential Building/House       10454.0
# 4  Unleashed Dog in Public        Public/Unfenced Area       11436.0
#
#        Incident Address      Street Name   Cross Street 1  \
# 0   199 MESEROLE STREET  MESEROLE STREET  HUMBOLDT STREET
# 1  15-30 HASSOCK STREET   HASSOCK STREET   REDFERN AVENUE
# 2         62 PARK PLACE       PARK PLACE         6 AVENUE
# 3      370 BROOK AVENUE     BROOK AVENUE  EAST 142 STREET
# 4     142-52 122 AVENUE       122 AVENUE         DEAD END
#
#         Cross Street 2 Intersection Street 1 Intersection Street 2  \
# 0      BUSHWICK AVENUE                   NaN                   NaN
# 1  BEACH CHANNEL DRIVE                   NaN                   NaN
# 2             5 AVENUE                   NaN                   NaN
# 3      EAST 143 STREET                   NaN                   NaN
# 4           143 STREET                   NaN                   NaN
#
#   Address Type          City Landmark    Facility Type  Status  \
# 0      ADDRESS      BROOKLYN      NaN         Precinct  Closed
# 1      ADDRESS  FAR ROCKAWAY      NaN         Precinct  Closed
# 2          NaN      BROOKLYN      NaN  School District  Closed
# 3      ADDRESS         BRONX      NaN         Precinct  Closed
# 4      ADDRESS       JAMAICA      NaN              NaN  Closed
#
#                  Due Date                             Resolution Description  \
# 0  01/24/2010 03:32:50 AM  The Police Department responded to the complai...
# 1  01/24/2010 03:49:13 AM  The Police Department responded to the complai...
# 2  01/27/2010 10:09:17 PM  The Department of Education is reviewing your ...
# 3  01/24/2010 06:55:44 AM  The Police Department responded to the complai...
# 4  02/22/2010 11:55:47 AM  The Department of Health and Mental Hygiene ha...
#
#   Resolution Action Updated Date Community Board           BBL   Borough  \
# 0         01/23/2010 07:59:55 PM     01 BROOKLYN  3.030450e+09  BROOKLYN
# 1         01/23/2010 08:49:01 PM       14 QUEENS  4.155010e+09    QUEENS
# 2         04/28/2010 02:56:43 PM     06 BROOKLYN  3.009410e+09  BROOKLYN
# 3         01/23/2010 11:15:53 PM        01 BRONX  2.022690e+09     BRONX
# 4         02/10/2010 11:51:00 AM       12 QUEENS  4.120380e+09    QUEENS
#
#    X Coordinate (State Plane)  Y Coordinate (State Plane)  \
# 0                   1000663.0                    197341.0
# 1                   1052873.0                    161058.0
# 2                    990769.0                    186649.0
# 3                   1007114.0                    234638.0
# 4                   1040656.0                    185333.0
#
#   Open Data Channel Type Park Facility Name Park Borough Vehicle Type  \
# 0                  PHONE        Unspecified     BROOKLYN          NaN
# 1                  PHONE        Unspecified       QUEENS          NaN
# 2                  PHONE     School - PS 77     BROOKLYN          NaN
# 3                  PHONE        Unspecified        BRONX          NaN
# 4                  PHONE        Unspecified       QUEENS          NaN
#
#   Taxi Company Borough Taxi Pick Up Location Bridge Highway Name  \
# 0                  NaN                   NaN                 NaN
# 1                  NaN                   NaN                 NaN
# 2                  NaN                   NaN                 NaN
# 3                  NaN                   NaN                 NaN
# 4                  NaN                   NaN                 NaN
#
#   Bridge Highway Direction Road Ramp Bridge Highway Segment   Latitude  \
# 0                      NaN       NaN                    NaN  40.708317
# 1                      NaN       NaN                    NaN  40.608478
# 2                      NaN       NaN                    NaN  40.678983
# 3                      NaN       NaN                    NaN  40.810673
# 4                      NaN       NaN                    NaN  40.675193
#
#    Longitude                                  Location Request_Closing_Time
# 0 -73.940800  (40.708316992485734, -73.94079991324266)      0 days 00:27:04
# 1 -73.752853     (40.6084776535044, -73.7528533996258)      0 days 00:59:48
# 2 -73.976497  (40.678982749894104, -73.97649694847125)     94 days 16:47:26
# 3 -73.917405   (40.81067332885121, -73.91740495406697)      0 days 00:20:09
# 4 -73.796650  (40.675193324229525, -73.79664995040157)     17 days 23:55:13

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10569 entries, 0 to 10568
# Data columns (total 42 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unique Key                      10569 non-null  int64
#  1   Created Date                    10569 non-null  datetime64[ns]
#  2   Closed Date                     10224 non-null  datetime64[ns]
#  3   Agency                          10569 non-null  object
#  4   Agency Name                     10569 non-null  object
#  5   Complaint Type                  10569 non-null  object
#  6   Descriptor                      10540 non-null  object
#  7   Location Type                   9163 non-null   object
#  8   Incident Zip                    10120 non-null  float64
#  9   Incident Address                8628 non-null   object
#  10  Street Name                     8626 non-null   object
#  11  Cross Street 1                  8800 non-null   object
#  12  Cross Street 2                  8789 non-null   object
#  13  Intersection Street 1           983 non-null    object
#  14  Intersection Street 2           983 non-null    object
#  15  Address Type                    10178 non-null  object
#  16  City                            10126 non-null  object
#  17  Landmark                        11 non-null     object
#  18  Facility Type                   1816 non-null   object
#  19  Status                          10569 non-null  object
#  20  Due Date                        3823 non-null   object
#  21  Resolution Description          10565 non-null  object
#  22  Resolution Action Updated Date  10488 non-null  object
#  23  Community Board                 10567 non-null  object
#  24  BBL                             8329 non-null   float64
#  25  Borough                         10567 non-null  object
#  26  X Coordinate (State Plane)      9475 non-null   float64
#  27  Y Coordinate (State Plane)      9475 non-null   float64
#  28  Open Data Channel Type          10568 non-null  object
#  29  Park Facility Name              10568 non-null  object
#  30  Park Borough                    10567 non-null  object
#  31  Vehicle Type                    7 non-null      object
#  32  Taxi Company Borough            9 non-null      object
#  33  Taxi Pick Up Location           110 non-null    object
#  34  Bridge Highway Name             32 non-null     object
#  35  Bridge Highway Direction        32 non-null     object
#  36  Road Ramp                       31 non-null     object
#  37  Bridge Highway Segment          31 non-null     object
#  38  Latitude                        9475 non-null   float64
#  39  Longitude                       9475 non-null   float64
#  40  Location                        9475 non-null   object
#  41  Request_Closing_Time            10224 non-null  timedelta64[ns]
# dtypes: datetime64[ns](2), float64(6), int64(1), object(32), timedelta64[ns](1)
# memory usage: 3.4+ MB

# %%
dataset.isna().sum()
# Out:
# Unique Key                            0
# Created Date                          0
# Closed Date                         345
# Agency                                0
# Agency Name                           0
# Complaint Type                        0
# Descriptor                           29
# Location Type                      1406
# Incident Zip                        449
# Incident Address                   1941
# Street Name                        1943
# Cross Street 1                     1769
# Cross Street 2                     1780
# Intersection Street 1              9586
# Intersection Street 2              9586
# Address Type                        391
# City                                443
# Landmark                          10558
# Facility Type                      8753
# Status                                0
# Due Date                           6746
# Resolution Description                4
# Resolution Action Updated Date       81
# Community Board                       2
# BBL                                2240
# Borough                               2
# X Coordinate (State Plane)         1094
# Y Coordinate (State Plane)         1094
# Open Data Channel Type                1
# Park Facility Name                    1
# Park Borough                          2
# Vehicle Type                      10562
# Taxi Company Borough              10560
# Taxi Pick Up Location             10459
# Bridge Highway Name               10537
# Bridge Highway Direction          10537
# Road Ramp                         10538
# Bridge Highway Segment            10538
# Latitude                           1094
# Longitude                          1094
# Location                           1094
# Request_Closing_Time                345
# dtype: int64

# %%
#dropping created and closed date
dataset.drop(['Closed Date','Created Date'],axis=1,inplace=True)

# %%
dataset.head(5)
# Out:
#    Unique Key Agency                              Agency Name  \
# 0    15790200   NYPD          New York City Police Department
# 1    15790201   NYPD          New York City Police Department
# 2    15790202    DOE        Central - Department of Education
# 3    15790203   NYPD          New York City Police Department
# 4    15790204  DOHMH  Department of Health and Mental Hygiene
#
#         Complaint Type               Descriptor               Location Type  \
# 0  Noise - Residential         Loud Music/Party  Residential Building/House
# 1  Noise - Residential         Loud Music/Party  Residential Building/House
# 2               Safety   Student Being Harassed                      School
# 3  Noise - Residential         Banging/Pounding  Residential Building/House
# 4        Unleashed Dog  Unleashed Dog in Public        Public/Unfenced Area
#
#    Incident Zip      Incident Address      Street Name   Cross Street 1  \
# 0       11206.0   199 MESEROLE STREET  MESEROLE STREET  HUMBOLDT STREET
# 1       11691.0  15-30 HASSOCK STREET   HASSOCK STREET   REDFERN AVENUE
# 2       11217.0         62 PARK PLACE       PARK PLACE         6 AVENUE
# 3       10454.0      370 BROOK AVENUE     BROOK AVENUE  EAST 142 STREET
# 4       11436.0     142-52 122 AVENUE       122 AVENUE         DEAD END
#
#         Cross Street 2 Intersection Street 1 Intersection Street 2  \
# 0      BUSHWICK AVENUE                   NaN                   NaN
# 1  BEACH CHANNEL DRIVE                   NaN                   NaN
# 2             5 AVENUE                   NaN                   NaN
# 3      EAST 143 STREET                   NaN                   NaN
# 4           143 STREET                   NaN                   NaN
#
#   Address Type          City Landmark    Facility Type  Status  \
# 0      ADDRESS      BROOKLYN      NaN         Precinct  Closed
# 1      ADDRESS  FAR ROCKAWAY      NaN         Precinct  Closed
# 2          NaN      BROOKLYN      NaN  School District  Closed
# 3      ADDRESS         BRONX      NaN         Precinct  Closed
# 4      ADDRESS       JAMAICA      NaN              NaN  Closed
#
#                  Due Date                             Resolution Description  \
# 0  01/24/2010 03:32:50 AM  The Police Department responded to the complai...
# 1  01/24/2010 03:49:13 AM  The Police Department responded to the complai...
# 2  01/27/2010 10:09:17 PM  The Department of Education is reviewing your ...
# 3  01/24/2010 06:55:44 AM  The Police Department responded to the complai...
# 4  02/22/2010 11:55:47 AM  The Department of Health and Mental Hygiene ha...
#
#   Resolution Action Updated Date Community Board           BBL   Borough  \
# 0         01/23/2010 07:59:55 PM     01 BROOKLYN  3.030450e+09  BROOKLYN
# 1         01/23/2010 08:49:01 PM       14 QUEENS  4.155010e+09    QUEENS
# 2         04/28/2010 02:56:43 PM     06 BROOKLYN  3.009410e+09  BROOKLYN
# 3         01/23/2010 11:15:53 PM        01 BRONX  2.022690e+09     BRONX
# 4         02/10/2010 11:51:00 AM       12 QUEENS  4.120380e+09    QUEENS
#
#    X Coordinate (State Plane)  Y Coordinate (State Plane)  \
# 0                   1000663.0                    197341.0
# 1                   1052873.0                    161058.0
# 2                    990769.0                    186649.0
# 3                   1007114.0                    234638.0
# 4                   1040656.0                    185333.0
#
#   Open Data Channel Type Park Facility Name Park Borough Vehicle Type  \
# 0                  PHONE        Unspecified     BROOKLYN          NaN
# 1                  PHONE        Unspecified       QUEENS          NaN
# 2                  PHONE     School - PS 77     BROOKLYN          NaN
# 3                  PHONE        Unspecified        BRONX          NaN
# 4                  PHONE        Unspecified       QUEENS          NaN
#
#   Taxi Company Borough Taxi Pick Up Location Bridge Highway Name  \
# 0                  NaN                   NaN                 NaN
# 1                  NaN                   NaN                 NaN
# 2                  NaN                   NaN                 NaN
# 3                  NaN                   NaN                 NaN
# 4                  NaN                   NaN                 NaN
#
#   Bridge Highway Direction Road Ramp Bridge Highway Segment   Latitude  \
# 0                      NaN       NaN                    NaN  40.708317
# 1                      NaN       NaN                    NaN  40.608478
# 2                      NaN       NaN                    NaN  40.678983
# 3                      NaN       NaN                    NaN  40.810673
# 4                      NaN       NaN                    NaN  40.675193
#
#    Longitude                                  Location Request_Closing_Time
# 0 -73.940800  (40.708316992485734, -73.94079991324266)      0 days 00:27:04
# 1 -73.752853     (40.6084776535044, -73.7528533996258)      0 days 00:59:48
# 2 -73.976497  (40.678982749894104, -73.97649694847125)     94 days 16:47:26
# 3 -73.917405   (40.81067332885121, -73.91740495406697)      0 days 00:20:09
# 4 -73.796650  (40.675193324229525, -73.79664995040157)     17 days 23:55:13

# %%
#dealing with missing values
dataset.isna().sum()
# Out:
# Unique Key                            0
# Agency                                0
# Agency Name                           0
# Complaint Type                        0
# Descriptor                           29
# Location Type                      1406
# Incident Zip                        449
# Incident Address                   1941
# Street Name                        1943
# Cross Street 1                     1769
# Cross Street 2                     1780
# Intersection Street 1              9586
# Intersection Street 2              9586
# Address Type                        391
# City                                443
# Landmark                          10558
# Facility Type                      8753
# Status                                0
# Due Date                           6746
# Resolution Description                4
# Resolution Action Updated Date       81
# Community Board                       2
# BBL                                2240
# Borough                               2
# X Coordinate (State Plane)         1094
# Y Coordinate (State Plane)         1094
# Open Data Channel Type                1
# Park Facility Name                    1
# Park Borough                          2
# Vehicle Type                      10562
# Taxi Company Borough              10560
# Taxi Pick Up Location             10459
# Bridge Highway Name               10537
# Bridge Highway Direction          10537
# Road Ramp                         10538
# Bridge Highway Segment            10538
# Latitude                           1094
# Longitude                          1094
# Location                           1094
# Request_Closing_Time                345
# dtype: int64

# %%
dataset['Agency'].value_counts()
dataset['Agency Name'].value_counts()
sns.countplot(dataset['Agency Name'])
# Out:
# HPD      5149
# NYPD     1598
# DOT       957
# DPR       561
# DSNY      548
# DEP       414
# DOF       387
# DOHMH     230
# DOB       197
# DHS       175
# TLC       145
# DCA       126
# DFTA       57
# DOE        11
# NYCEM       8
# DOITT       5
# 3-1-1       1
# Name: Agency, dtype: int64
# Department of Housing Preservation and Development             5149
# New York City Police Department                                1597
# Department of Transportation                                    957
# Department of Parks and Recreation                              561
# Department of Sanitation                                        548
# Department of Environmental Protection                          414
# Department of Health and Mental Hygiene                         230
# Department of Buildings                                         197
# DHS Advantage Programs                                          175
# Taxi and Limousine Commission                                   141
# Department of Consumer Affairs                                  126
# Senior Citizen Rent Increase Exemption Unit                     103
# Refunds and Adjustments                                          73
# Department for the Aging                                         57
# Correspondence Unit                                              46
# Property Exec Office                                             45
# Exemption Unit                                                   32
# Adjudication - Hearing by Mail                                   27
# Revenue Accounting                                               23
# Discrepancy and Billing                                          17
# Central - Department of Education                                 8
# NYC Emergency Management                                          8
# Payment Operations                                                6
# Dunning Unit                                                      5
# Department of Information Technology and Telecommunications       5
# Correspondence - Taxi and Limousine Commission                    4
# Valuation Policy                                                  3
# Exemption Policy Unit                                             3
# RPIE Unit                                                         2
# Land Records                                                      1
# 3-1-1 Call Center                                                 1
# Condo or CoOp Unit                                                1
# School - PS 38 The Pacific                                        1
# School - IS 61 William A Morris                                   1
# Investigation Review Section                                      1
# School - Port Richmond High School                                1
# Name: Agency Name, dtype: int64
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
dataset['Complaint Type'].value_counts().head()
plot=sns.countplot(dataset['Complaint Type'])
plot.set_xticklabels(plot.get_xticklabels(),rotation=90)
# Out:
# Blocked Driveway           100881
# Illegal Parking             92679
# Noise - Street/Sidewalk     51692
# Noise - Commercial          44109
# Derelict Vehicle            21661
# Name: Complaint Type, dtype: int64
# [Text(0, 0, 'Noise - Street/Sidewalk'),
#  Text(0, 0, 'Blocked Driveway'),
#  Text(0, 0, 'Illegal Parking'),
#  Text(0, 0, 'Derelict Vehicle'),
#  Text(0, 0, 'Noise - Commercial'),
#  Text(0, 0, 'Noise - House of Worship'),
#  Text(0, 0, 'Posting Advertisement'),
#  Text(0, 0, 'Noise - Vehicle'),
#  Text(0, 0, 'Animal Abuse'),
#  Text(0, 0, 'Vending'),
#  Text(0, 0, 'Traffic'),
#  Text(0, 0, 'Drinking'),
#  Text(0, 0, 'Bike/Roller/Skate Chronic'),
#  Text(0, 0, 'Panhandling'),
#  Text(0, 0, 'Noise - Park'),
#  Text(0, 0, 'Homeless Encampment'),
#  Text(0, 0, 'Urinating in Public'),
#  Text(0, 0, 'Graffiti'),
#  Text(0, 0, 'Disorderly Youth'),
#  Text(0, 0, 'Illegal Fireworks'),
#  Text(0, 0, 'Ferry Complaint'),
#  Text(0, 0, 'Agency Issues'),
#  Text(0, 0, 'Squeegee'),
#  Text(0, 0, 'Animal in a Park')]

# %%
dataset['Descriptor'].describe()
# Out:
# count        358057
# unique           45
# top       No Access
# freq          75888
# Name: Descriptor, dtype: object

# %%
dataset['Descriptor'].value_counts().head(5)
# Out:
# No Access                        75888
# Loud Music/Party                 69708
# Posted Parking Sign Violation    27200
# Partial Access                   24993
# Loud Talking                     23810
# Name: Descriptor, dtype: int64

# %%
plot2=sns.countplot(dataset['Descriptor'])
plot2.set_xticklabels(plot.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'Noise - Street/Sidewalk'),
#  Text(0, 0, 'Blocked Driveway'),
#  Text(0, 0, 'Illegal Parking'),
#  Text(0, 0, 'Derelict Vehicle'),
#  Text(0, 0, 'Noise - Commercial'),
#  Text(0, 0, 'Noise - House of Worship'),
#  Text(0, 0, 'Posting Advertisement'),
#  Text(0, 0, 'Noise - Vehicle'),
#  Text(0, 0, 'Animal Abuse'),
#  Text(0, 0, 'Vending'),
#  Text(0, 0, 'Traffic'),
#  Text(0, 0, 'Drinking'),
#  Text(0, 0, 'Bike/Roller/Skate Chronic'),
#  Text(0, 0, 'Panhandling'),
#  Text(0, 0, 'Noise - Park'),
#  Text(0, 0, 'Homeless Encampment'),
#  Text(0, 0, 'Urinating in Public'),
#  Text(0, 0, 'Graffiti'),
#  Text(0, 0, 'Disorderly Youth'),
#  Text(0, 0, 'Illegal Fireworks'),
#  Text(0, 0, 'Ferry Complaint'),
#  Text(0, 0, 'Agency Issues'),
#  Text(0, 0, 'Squeegee'),
#  Text(0, 0, 'Animal in a Park')]

# %%
dataset['Location Type'].isna().sum()
# Out:
# 1406

# %%
dataset['Location Type'].value_counts().head()
# Out:
# RESIDENTIAL BUILDING          5099
# Street                        1108
# Residential Building/House     828
# Street/Sidewalk                615
# Sidewalk                       332
# Name: Location Type, dtype: int64

# %%
dataset['Location Type'].fillna(value='Street/Sidewalk',inplace =True)
plot3=sns.countplot(dataset['Location Type'])
plot3.set_xticklabels(plot3.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'Street/Sidewalk'),
#  Text(0, 0, 'Club/Bar/Restaurant'),
#  Text(0, 0, 'Store/Commercial'),
#  Text(0, 0, 'House of Worship'),
#  Text(0, 0, 'Residential Building/House'),
#  Text(0, 0, 'Residential Building'),
#  Text(0, 0, 'Park/Playground'),
#  Text(0, 0, 'Vacant Lot'),
#  Text(0, 0, 'House and Store'),
#  Text(0, 0, 'Highway'),
#  Text(0, 0, 'Commercial'),
#  Text(0, 0, 'Roadway Tunnel'),
#  Text(0, 0, 'Subway Station'),
#  Text(0, 0, 'Parking Lot'),
#  Text(0, 0, 'Bridge'),
#  Text(0, 0, 'Terminal'),
#  Text(0, 0, 'Ferry'),
#  Text(0, 0, 'Park')]

# %%
dataset['Incident Zip'].value_counts().head()
dataset['Incident Zip'].isna().sum()
dataset['Incident Zip'].fillna(value=11385,inplace=True)
# Out:
# 11385.0    6396
# 11368.0    5384
# 11234.0    5199
# 11211.0    4854
# 11377.0    4525
# Name: Incident Zip, dtype: int64
# 2998

# %%
dataset['Address Type'].value_counts()
dataset['Address Type'].fillna(value='Address',inplace=True)
sns.countplot(dataset['Address Type'])
# Out:
# ADDRESS         292699
# INTERSECTION     50514
# BLOCKFACE        13786
# LATLONG           3931
# PLACENAME          376
# Name: Address Type, dtype: int64

# %%
dataset.drop(['Latitude', 'Longitude','Location','Y Coordinate (State Plane)','Landmark'],axis=1,inplace=True)

# %%
dataset.isna().sum()
# Out:
# Unique Key                            0
# Agency                                0
# Agency Name                           0
# Complaint Type                        0
# Descriptor                           29
# Location Type                      1406
# Incident Zip                        449
# Incident Address                   1941
# Street Name                        1943
# Cross Street 1                     1769
# Cross Street 2                     1780
# Intersection Street 1              9586
# Intersection Street 2              9586
# Address Type                        391
# City                                443
# Facility Type                      8753
# Status                                0
# Due Date                           6746
# Resolution Description                4
# Resolution Action Updated Date       81
# Community Board                       2
# BBL                                2240
# Borough                               2
# X Coordinate (State Plane)         1094
# Open Data Channel Type                1
# Park Facility Name                    1
# Park Borough                          2
# Vehicle Type                      10562
# Taxi Company Borough              10560
# Taxi Pick Up Location             10459
# Bridge Highway Name               10537
# Bridge Highway Direction          10537
# Road Ramp                         10538
# Bridge Highway Segment            10538
# Request_Closing_Time                345
# dtype: int64

# %%
dataset['City'].value_counts().head()
dataset['Facility Type'].value_counts().head()
# Out:
# BROOKLYN         3203
# BRONX            2313
# NEW YORK         1976
# STATEN ISLAND     429
# JAMAICA           286
# Name: City, dtype: int64
# Precinct           1597
# DSNY Garage         208
# School District       8
# School                3
# Name: Facility Type, dtype: int64

# %%
dataset['City'].fillna(value='BROOKLYN',inplace=True)
dataset['City'].value_counts().head()
plot4=sns.countplot(x=dataset['City'])
plot4.set_xticklabels(plot.get_xticklabels(),rotation=90)
# Out:
# BROOKLYN         3646
# BRONX            2313
# NEW YORK         1976
# STATEN ISLAND     429
# JAMAICA           286
# Name: City, dtype: int64
# [Text(0, 0, 'Noise - Residential'),
#  Text(0, 0, 'Safety'),
#  Text(0, 0, 'Unleashed Dog'),
#  Text(0, 0, 'Noise - Street/Sidewalk'),
#  Text(0, 0, 'Traffic/Illegal Parking'),
#  Text(0, 0, 'Vending'),
#  Text(0, 0, 'Housing Options'),
#  Text(0, 0, 'Water System'),
#  Text(0, 0, 'Blocked Driveway'),
#  Text(0, 0, 'Noise - Vehicle'),
#  Text(0, 0, 'Sidewalk Condition'),
#  Text(0, 0, 'Root/Sewer/Sidewalk Condition'),
#  Text(0, 0, 'Broken Muni Meter'),
#  Text(0, 0, 'SCRIE'),
#  Text(0, 0, 'Broken Parking Meter'),
#  Text(0, 0, 'Derelict Vehicle'),
#  Text(0, 0, 'Rodent'),
#  Text(0, 0, 'Taxi Complaint'),
#  Text(0, 0, 'Drinking'),
#  Text(0, 0, 'Noise - Commercial'),
#  Text(0, 0, 'DOF Parking - Payment Issue'),
#  Text(0, 0, 'Indoor Air Quality'),
#  Text(0, 0, 'DOF Property - Request Copy'),
#  Text(0, 0, 'HPD Literature Request'),
#  Text(0, 0, 'Disorderly Youth'),
#  Text(0, 0, 'Consumer Complaint'),
#  Text(0, 0, 'Bus Stop Shelter Placement'),
#  Text(0, 0, 'Traffic Signal Condition'),
#  Text(0, 0, 'Maintenance or Facility'),
#  Text(0, 0, 'DCA / DOH New License Application Request'),
#  Text(0, 0, 'DHS Advantage - Tenant'),
#  Text(0, 0, 'Non-Emergency Police Matter'),
#  Text(0, 0, 'Noise - House of Worship'),
#  Text(0, 0, 'Street Condition'),
#  Text(0, 0, 'Damaged Tree'),
#  Text(0, 0, 'Food Poisoning'),
#  Text(0, 0, 'Curb Condition'),
#  Text(0, 0, 'Street Sign - Dangling'),
#  Text(0, 0, 'Smoking'),
#  Text(0, 0, 'DOF Parking - Request Copy'),
#  Text(0, 0, 'Eviction'),
#  Text(0, 0, 'Street Sign - Damaged'),
#  Text(0, 0, 'Bike/Roller/Skate Chronic'),
#  Text(0, 0, 'Literature Request'),
#  Text(0, 0, 'Highway Condition'),
#  Text(0, 0, 'Ferry Permit'),
#  Text(0, 0, 'Bridge Condition'),
#  Text(0, 0, 'Bottled Water'),
#  Text(0, 0, 'Found Property'),
#  Text(0, 0, 'Taxi Compliment'),
#  Text(0, 0, 'Food Establishment'),
#  Text(0, 0, 'Dead Tree'),
#  Text(0, 0, 'New Tree Request'),
#  Text(0, 0, 'Bus Stop Shelter Complaint'),
#  Text(0, 0, 'Street Sign - Missing'),
#  Text(0, 0, 'School Maintenance'),
#  Text(0, 0, 'NONCONST'),
#  Text(0, 0, 'ELECTRIC'),
#  Text(0, 0, 'HEATING'),
#  Text(0, 0, 'PLUMBING'),
#  Text(0, 0, 'PAINT - PLASTER'),
#  Text(0, 0, 'Lead'),
#  Text(0, 0, 'APPLIANCE'),
#  Text(0, 0, 'GENERAL CONSTRUCTION'),
#  Text(0, 0, 'Street Light Condition'),
#  Text(0, 0, 'Derelict Vehicles'),
#  Text(0, 0, 'DOF Property - Reduction Issue'),
#  Text(0, 0, 'Animal in a Park'),
#  Text(0, 0, 'Sewer'),
#  Text(0, 0, 'DOF Property - Owner Issue'),
#  Text(0, 0, 'Water Conservation'),
#  Text(0, 0, 'CONSTRUCTION'),
#  Text(0, 0, 'Noise'),
#  Text(0, 0, 'Asbestos'),
#  Text(0, 0, 'Hazardous Materials'),
#  Text(0, 0, 'Air Quality'),
#  Text(0, 0, 'Cranes and Derricks'),
#  Text(0, 0, 'General Construction/Plumbing'),
#  Text(0, 0, 'Elevator'),
#  Text(0, 0, 'Building/Use'),
#  Text(0, 0, 'BEST/Site Safety'),
#  Text(0, 0, 'Plumbing'),
#  Text(0, 0, 'Electrical'),
#  Text(0, 0, 'Special Projects Inspection Team (SPIT)'),
#  Text(0, 0, 'Boilers'),
#  Text(0, 0, 'Investigations and Discipline (IAD)'),
#  Text(0, 0, 'Graffiti'),
#  Text(0, 0, 'Unsanitary Animal Pvt Property'),
#  Text(0, 0, 'Noise - Park'),
#  Text(0, 0, 'Window Guard'),
#  Text(0, 0, 'Health'),
#  Text(0, 0, 'Illegal Animal Sold')]

# %%
dataset.isna().sum()
# Out:
# Unique Key                            0
# Agency                                0
# Agency Name                           0
# Complaint Type                        0
# Descriptor                           29
# Location Type                      1406
# Incident Zip                        449
# Incident Address                   1941
# Street Name                        1943
# Cross Street 1                     1769
# Cross Street 2                     1780
# Intersection Street 1              9586
# Intersection Street 2              9586
# Address Type                        391
# City                                  0
# Facility Type                      8753
# Status                                0
# Due Date                           6746
# Resolution Description                4
# Resolution Action Updated Date       81
# Community Board                       2
# BBL                                2240
# Borough                               2
# X Coordinate (State Plane)         1094
# Open Data Channel Type                1
# Park Facility Name                    1
# Park Borough                          2
# Vehicle Type                      10562
# Taxi Company Borough              10560
# Taxi Pick Up Location             10459
# Bridge Highway Name               10537
# Bridge Highway Direction          10537
# Road Ramp                         10538
# Bridge Highway Segment            10538
# Request_Closing_Time                345
# dtype: int64

# %%
dataset['Request_Closing_Time'].head()
# Out:
# 0    0 days 00:27:04
# 1    0 days 00:59:48
# 2   94 days 16:47:26
# 3    0 days 00:20:09
# 4   17 days 23:55:13
# Name: Request_Closing_Time, dtype: timedelta64[ns]

# %%
dataset['Request_Closing_Time'].fillna(value=dataset['Request_Closing_Time'].mean(),inplace=True)

# %%
dataset['Request_Closing_Time'].isna().sum()
# Out:
# 0

# %%
dataset.head(10)
# Out:
#    Unique Key Agency                              Agency Name  \
# 0    15790200   NYPD          New York City Police Department
# 1    15790201   NYPD          New York City Police Department
# 2    15790202    DOE        Central - Department of Education
# 3    15790203   NYPD          New York City Police Department
# 4    15790204  DOHMH  Department of Health and Mental Hygiene
# 5    15790205   NYPD          New York City Police Department
# 6    15790206   NYPD          New York City Police Department
# 7    15790207   NYPD          New York City Police Department
# 8    15790208   NYPD          New York City Police Department
# 9    15790209   DFTA                 Department for the Aging
#
#             Complaint Type                     Descriptor  \
# 0      Noise - Residential               Loud Music/Party
# 1      Noise - Residential               Loud Music/Party
# 2                   Safety         Student Being Harassed
# 3      Noise - Residential               Banging/Pounding
# 4            Unleashed Dog        Unleashed Dog in Public
# 5  Noise - Street/Sidewalk                   Loud Talking
# 6  Traffic/Illegal Parking                Blocked Hydrant
# 7  Traffic/Illegal Parking  Posted Parking Sign Violation
# 8                  Vending             In Prohibited Area
# 9          Housing Options          Other Housing Options
#
#                 Location Type  Incident Zip      Incident Address  \
# 0  Residential Building/House       11206.0   199 MESEROLE STREET
# 1  Residential Building/House       11691.0  15-30 HASSOCK STREET
# 2                      School       11217.0         62 PARK PLACE
# 3  Residential Building/House       10454.0      370 BROOK AVENUE
# 4        Public/Unfenced Area       11436.0     142-52 122 AVENUE
# 5             Street/Sidewalk       10469.0                   NaN
# 6             Street/Sidewalk       10305.0      292 MAJOR AVENUE
# 7             Street/Sidewalk       10023.0   178 COLUMBUS AVENUE
# 8             Street/Sidewalk       10023.0         1900 BROADWAY
# 9              Senior Address       11221.0                   NaN
#
#        Street Name   Cross Street 1       Cross Street 2  \
# 0  MESEROLE STREET  HUMBOLDT STREET      BUSHWICK AVENUE
# 1   HASSOCK STREET   REDFERN AVENUE  BEACH CHANNEL DRIVE
# 2       PARK PLACE         6 AVENUE             5 AVENUE
# 3     BROOK AVENUE  EAST 142 STREET      EAST 143 STREET
# 4       122 AVENUE         DEAD END           143 STREET
# 5              NaN              NaN                  NaN
# 6     MAJOR AVENUE        SAND LANE       LINWOOD AVENUE
# 7  COLUMBUS AVENUE   WEST 67 STREET       WEST 68 STREET
# 8         BROADWAY   WEST 63 STREET       WEST 64 STREET
# 9              NaN              NaN                  NaN
#
#   Intersection Street 1 Intersection Street 2  Address Type           City  \
# 0                   NaN                   NaN       ADDRESS       BROOKLYN
# 1                   NaN                   NaN       ADDRESS   FAR ROCKAWAY
# 2                   NaN                   NaN           NaN       BROOKLYN
# 3                   NaN                   NaN       ADDRESS          BRONX
# 4                   NaN                   NaN       ADDRESS        JAMAICA
# 5          ARNOW AVENUE           HONE AVENUE  INTERSECTION          BRONX
# 6                   NaN                   NaN       ADDRESS  STATEN ISLAND
# 7                   NaN                   NaN       ADDRESS       NEW YORK
# 8                   NaN                   NaN       ADDRESS       NEW YORK
# 9                   NaN                   NaN       ADDRESS       BROOKLYN
#
#      Facility Type  Status                Due Date  \
# 0         Precinct  Closed  01/24/2010 03:32:50 AM
# 1         Precinct  Closed  01/24/2010 03:49:13 AM
# 2  School District  Closed  01/27/2010 10:09:17 PM
# 3         Precinct  Closed  01/24/2010 06:55:44 AM
# 4              NaN  Closed  02/22/2010 11:55:47 AM
# 5         Precinct  Closed  01/23/2010 08:37:50 PM
# 6         Precinct  Closed  01/23/2010 08:42:13 PM
# 7         Precinct  Closed  01/23/2010 09:21:10 PM
# 8         Precinct  Closed  01/23/2010 09:28:38 PM
# 9              NaN  Closed  02/06/2010 01:52:22 PM
#
#                               Resolution Description  \
# 0  The Police Department responded to the complai...
# 1  The Police Department responded to the complai...
# 2  The Department of Education is reviewing your ...
# 3  The Police Department responded to the complai...
# 4  The Department of Health and Mental Hygiene ha...
# 5  The Police Department responded to the complai...
# 6  The Police Department responded to the complai...
# 7  The Police Department responded to the complai...
# 8  The Police Department responded to the complai...
# 9  The Department for the Aging contacted you and...
#
#   Resolution Action Updated Date   Community Board           BBL  \
# 0         01/23/2010 07:59:55 PM       01 BROOKLYN  3.030450e+09
# 1         01/23/2010 08:49:01 PM         14 QUEENS  4.155010e+09
# 2         04/28/2010 02:56:43 PM       06 BROOKLYN  3.009410e+09
# 3         01/23/2010 11:15:53 PM          01 BRONX  2.022690e+09
# 4         02/10/2010 11:51:00 AM         12 QUEENS  4.120380e+09
# 5         01/23/2010 04:30:17 PM          11 BRONX           NaN
# 6         01/23/2010 07:10:35 PM  02 STATEN ISLAND  5.032670e+09
# 7         01/23/2010 03:58:03 PM      07 MANHATTAN  1.011398e+09
# 8         01/23/2010 03:57:00 PM      07 MANHATTAN  1.011168e+09
# 9         01/26/2010 09:59:03 AM       04 BROOKLYN           NaN
#
#          Borough  X Coordinate (State Plane) Open Data Channel Type  \
# 0       BROOKLYN                   1000663.0                  PHONE
# 1         QUEENS                   1052873.0                  PHONE
# 2       BROOKLYN                    990769.0                  PHONE
# 3          BRONX                   1007114.0                  PHONE
# 4         QUEENS                   1040656.0                  PHONE
# 5          BRONX                   1023618.0                  PHONE
# 6  STATEN ISLAND                    964196.0                  PHONE
# 7      MANHATTAN                    989585.0                  PHONE
# 8      MANHATTAN                    989194.0                  PHONE
# 9       BROOKLYN                         NaN                  PHONE
#
#   Park Facility Name   Park Borough Vehicle Type Taxi Company Borough  \
# 0        Unspecified       BROOKLYN          NaN                  NaN
# 1        Unspecified         QUEENS          NaN                  NaN
# 2     School - PS 77       BROOKLYN          NaN                  NaN
# 3        Unspecified          BRONX          NaN                  NaN
# 4        Unspecified         QUEENS          NaN                  NaN
# 5        Unspecified          BRONX          NaN                  NaN
# 6        Unspecified  STATEN ISLAND          NaN                  NaN
# 7        Unspecified      MANHATTAN          NaN                  NaN
# 8        Unspecified      MANHATTAN          NaN                  NaN
# 9        Unspecified       BROOKLYN          NaN                  NaN
#
#   Taxi Pick Up Location Bridge Highway Name Bridge Highway Direction  \
# 0                   NaN                 NaN                      NaN
# 1                   NaN                 NaN                      NaN
# 2                   NaN                 NaN                      NaN
# 3                   NaN                 NaN                      NaN
# 4                   NaN                 NaN                      NaN
# 5                   NaN                 NaN                      NaN
# 6                   NaN                 NaN                      NaN
# 7                   NaN                 NaN                      NaN
# 8                   NaN                 NaN                      NaN
# 9                   NaN                 NaN                      NaN
#
#   Road Ramp Bridge Highway Segment Request_Closing_Time
# 0       NaN                    NaN      0 days 00:27:04
# 1       NaN                    NaN      0 days 00:59:48
# 2       NaN                    NaN     94 days 16:47:26
# 3       NaN                    NaN      0 days 00:20:09
# 4       NaN                    NaN     17 days 23:55:13
# 5       NaN                    NaN      0 days 03:52:27
# 6       NaN                    NaN      0 days 06:28:22
# 7       NaN                    NaN      0 days 02:36:53
# 8       NaN                    NaN      0 days 02:28:22
# 9       NaN                    NaN      2 days 20:06:41

# %%
dataset['Status'].value_counts()
# Out:
# Closed         10210
# Assigned         146
# Pending          130
# Open              82
# Unspecified        1
# Name: Status, dtype: int64

# %%
sns.countplot(dataset['Status'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#bivariate analysis
#the most common complaint
dataset['Complaint Type'].value_counts().head(6)
# Out:
# HEATING                 2138
# PLUMBING                 885
# Noise - Residential      818
# GENERAL CONSTRUCTION     769
# PAINT - PLASTER          564
# Damaged Tree             379
# Name: Complaint Type, dtype: int64

# %%
dataset.head(3)
# Out:
#    Unique Key Agency                        Agency Name       Complaint Type  \
# 0    15790200   NYPD    New York City Police Department  Noise - Residential
# 1    15790201   NYPD    New York City Police Department  Noise - Residential
# 2    15790202    DOE  Central - Department of Education               Safety
#
#                Descriptor               Location Type  Incident Zip  \
# 0        Loud Music/Party  Residential Building/House       11206.0
# 1        Loud Music/Party  Residential Building/House       11691.0
# 2  Student Being Harassed                      School       11217.0
#
#        Incident Address      Street Name   Cross Street 1  \
# 0   199 MESEROLE STREET  MESEROLE STREET  HUMBOLDT STREET
# 1  15-30 HASSOCK STREET   HASSOCK STREET   REDFERN AVENUE
# 2         62 PARK PLACE       PARK PLACE         6 AVENUE
#
#         Cross Street 2 Intersection Street 1 Intersection Street 2  \
# 0      BUSHWICK AVENUE                   NaN                   NaN
# 1  BEACH CHANNEL DRIVE                   NaN                   NaN
# 2             5 AVENUE                   NaN                   NaN
#
#   Address Type          City    Facility Type  Status                Due Date  \
# 0      ADDRESS      BROOKLYN         Precinct  Closed  01/24/2010 03:32:50 AM
# 1      ADDRESS  FAR ROCKAWAY         Precinct  Closed  01/24/2010 03:49:13 AM
# 2          NaN      BROOKLYN  School District  Closed  01/27/2010 10:09:17 PM
#
#                               Resolution Description  \
# 0  The Police Department responded to the complai...
# 1  The Police Department responded to the complai...
# 2  The Department of Education is reviewing your ...
#
#   Resolution Action Updated Date Community Board           BBL   Borough  \
# 0         01/23/2010 07:59:55 PM     01 BROOKLYN  3.030450e+09  BROOKLYN
# 1         01/23/2010 08:49:01 PM       14 QUEENS  4.155010e+09    QUEENS
# 2         04/28/2010 02:56:43 PM     06 BROOKLYN  3.009410e+09  BROOKLYN
#
#    X Coordinate (State Plane) Open Data Channel Type Park Facility Name  \
# 0                   1000663.0                  PHONE        Unspecified
# 1                   1052873.0                  PHONE        Unspecified
# 2                    990769.0                  PHONE     School - PS 77
#
#   Park Borough Vehicle Type Taxi Company Borough Taxi Pick Up Location  \
# 0     BROOKLYN          NaN                  NaN                   NaN
# 1       QUEENS          NaN                  NaN                   NaN
# 2     BROOKLYN          NaN                  NaN                   NaN
#
#   Bridge Highway Name Bridge Highway Direction Road Ramp  \
# 0                 NaN                      NaN       NaN
# 1                 NaN                      NaN       NaN
# 2                 NaN                      NaN       NaN
#
#   Bridge Highway Segment Request_Closing_Time
# 0                    NaN      0 days 00:27:04
# 1                    NaN      0 days 00:59:48
# 2                    NaN     94 days 16:47:26

# %%
desc=dataset.groupby(by='Complaint Type')['Descriptor'].agg('count')
desc
# Out:
# Complaint Type
# APPLIANCE              93
# Air Quality            15
# Alzheimer's Care        0
# Animal in a Park       18
# Asbestos                2
#                      ...
# Vending                10
# Water Conservation      9
# Water System          163
# Weatherization          0
# Window Guard            9
# Name: Descriptor, Length: 141, dtype: int64

# %%
#City with their status
dataset.loc[dataset['City']=='NEW YORK',]['Borough'].value_counts()
# Out:
# MANHATTAN      1025
# Unspecified     947
# BROOKLYN          2
# BRONX             2
# Name: Borough, dtype: int64

# %%
#Newyork city has how many boroughs and whats their status 
sns.countplot(x=dataset.loc[dataset['City']=='NEW YORK',]['Borough'],hue='Status',data=dataset)

# %%
#Newyork city has max complaints of which complaint type?
dataset.loc[dataset['City']=='NEW YORK',:]['Complaint Type'].value_counts()
# Out:
# HEATING                 413
# Noise - Residential     164
# GENERAL CONSTRUCTION    163
# PLUMBING                149
# Street Condition        104
#                        ...
# Derelict Vehicles         1
# Cranes and Derricks       1
# Asbestos                  1
# Radioactive Material      1
# Graffiti                  1
# Name: Complaint Type, Length: 93, dtype: int64

# %%
#Countplot to show Newyork city has max complaints of which complaint type?
plot=sns.countplot(x=dataset.loc[dataset['City']=='NEW YORK',:]['Complaint Type'])
plot.set_xticklabels(plot.get_xticklabels(),rotation = 90)
# Out:
# [Text(0, 0, 'Noise - Street/Sidewalk'),
#  Text(0, 0, 'Illegal Parking'),
#  Text(0, 0, 'Noise - House of Worship'),
#  Text(0, 0, 'Noise - Commercial'),
#  Text(0, 0, 'Blocked Driveway'),
#  Text(0, 0, 'Vending'),
#  Text(0, 0, 'Noise - Vehicle'),
#  Text(0, 0, 'Panhandling'),
#  Text(0, 0, 'Animal Abuse'),
#  Text(0, 0, 'Noise - Park'),
#  Text(0, 0, 'Homeless Encampment'),
#  Text(0, 0, 'Traffic'),
#  Text(0, 0, 'Derelict Vehicle'),
#  Text(0, 0, 'Drinking'),
#  Text(0, 0, 'Urinating in Public'),
#  Text(0, 0, 'Bike/Roller/Skate Chronic'),
#  Text(0, 0, 'Graffiti'),
#  Text(0, 0, 'Posting Advertisement'),
#  Text(0, 0, 'Disorderly Youth'),
#  Text(0, 0, 'Illegal Fireworks'),
#  Text(0, 0, 'Squeegee')]

# %%
#Avg time taken to solve a case in Newyork city
dataset.loc[(dataset['City']=='NEW YORK')&(dataset['Status']=='Closed'),:]['Request_Closing_Time'].mean()
# Out:
# Timedelta('23 days 10:44:28.022715539')

# %%
dataset.loc[(dataset['City']=='NEW YORK')&(dataset['Status']=='Closed'),:]['Request_Closing_Time'].std()
# Out:
# Timedelta('0 days 04:32:14.424673')

# %%
dataset['Borough'].value_counts()
# Out:
# Unspecified      5356
# QUEENS           1507
# BROOKLYN         1394
# MANHATTAN        1110
# BRONX             847
# STATEN ISLAND     353
# Name: Borough, dtype: int64

# %%
dataset['Location Type'].value_counts()
# Out:
# RESIDENTIAL BUILDING             5099
# Street                           1108
# Residential Building/House        828
# Street/Sidewalk                   615
# Sidewalk                          332
# Tenant Address                    175
# Property Address                  160
# Senior Address                    151
# Other                             150
# Club/Bar/Restaurant                97
# 3+ Family Apartment Building       46
# Restaurant/Bar/Deli/Bakery         44
# Store/Commercial                   42
# Park                               36
# 1-2 Family Dwelling                33
# 3+ Family Apt. Building            33
# Lot                                27
# Highway                            23
# Bus Stop Shelter                   20
# Other (Explain Below)              17
# School                             12
# Commercial Building                10
# 3+ Family Mixed Use Building        9
# Bridge                              8
# Park/Playground                     8
# Residential Building                8
# Address Unknown                     7
# Vacant Lot                          7
# Residential                         7
# House of Worship                    6
# Street and Sidewalk                 5
# Public/Unfenced Area                5
# Building (Non-Residential)          4
# Taxi                                3
# Vacant Building                     3
# Comercial                           2
# Ferry                               2
# Terminal                            2
# Recreation Center                   2
# 1-2 Family Mixed Use Building       2
# Street/Curbside                     2
# Service Provider                    1
# Soup Kitchen                        1
# Senior Center                       1
# Government Building                 1
# Public Garden                       1
# Tattoo Parlor                       1
# Beach                               1
# Residence                           1
# Roadway Tunnel                      1
# Food Cart Vendor                    1
# Parking Lot/Garage                  1
# Restaurant                          1
# Roadway                             1
# Name: Location Type, dtype: int64

# %%
#Top Location type and their countplot with hues='Borough'
sns.countplot(dataset.loc[dataset['Location Type'].isin(['Street/Sidewalk','Store/Commercial','Club/Bar/Restaurant'])]
              ['Location Type'],data=dataset,hue='Borough')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import datetime
dataset['year'] = pd.DatetimeIndex(dataset['Due Date']).year
dataset.head()
# Out:
#    Unique Key Agency                              Agency Name  \
# 0    15790200   NYPD          New York City Police Department
# 1    15790201   NYPD          New York City Police Department
# 2    15790202    DOE        Central - Department of Education
# 3    15790203   NYPD          New York City Police Department
# 4    15790204  DOHMH  Department of Health and Mental Hygiene
#
#         Complaint Type               Descriptor               Location Type  \
# 0  Noise - Residential         Loud Music/Party  Residential Building/House
# 1  Noise - Residential         Loud Music/Party  Residential Building/House
# 2               Safety   Student Being Harassed                      School
# 3  Noise - Residential         Banging/Pounding  Residential Building/House
# 4        Unleashed Dog  Unleashed Dog in Public        Public/Unfenced Area
#
#    Incident Zip      Incident Address      Street Name   Cross Street 1  \
# 0       11206.0   199 MESEROLE STREET  MESEROLE STREET  HUMBOLDT STREET
# 1       11691.0  15-30 HASSOCK STREET   HASSOCK STREET   REDFERN AVENUE
# 2       11217.0         62 PARK PLACE       PARK PLACE         6 AVENUE
# 3       10454.0      370 BROOK AVENUE     BROOK AVENUE  EAST 142 STREET
# 4       11436.0     142-52 122 AVENUE       122 AVENUE         DEAD END
#
#         Cross Street 2 Intersection Street 1 Intersection Street 2  \
# 0      BUSHWICK AVENUE                   NaN                   NaN
# 1  BEACH CHANNEL DRIVE                   NaN                   NaN
# 2             5 AVENUE                   NaN                   NaN
# 3      EAST 143 STREET                   NaN                   NaN
# 4           143 STREET                   NaN                   NaN
#
#   Address Type          City    Facility Type  Status                Due Date  \
# 0      ADDRESS      BROOKLYN         Precinct  Closed  01/24/2010 03:32:50 AM
# 1      ADDRESS  FAR ROCKAWAY         Precinct  Closed  01/24/2010 03:49:13 AM
# 2          NaN      BROOKLYN  School District  Closed  01/27/2010 10:09:17 PM
# 3      ADDRESS         BRONX         Precinct  Closed  01/24/2010 06:55:44 AM
# 4      ADDRESS       JAMAICA              NaN  Closed  02/22/2010 11:55:47 AM
#
#                               Resolution Description  \
# 0  The Police Department responded to the complai...
# 1  The Police Department responded to the complai...
# 2  The Department of Education is reviewing your ...
# 3  The Police Department responded to the complai...
# 4  The Department of Health and Mental Hygiene ha...
#
#   Resolution Action Updated Date Community Board           BBL   Borough  \
# 0         01/23/2010 07:59:55 PM     01 BROOKLYN  3.030450e+09  BROOKLYN
# 1         01/23/2010 08:49:01 PM       14 QUEENS  4.155010e+09    QUEENS
# 2         04/28/2010 02:56:43 PM     06 BROOKLYN  3.009410e+09  BROOKLYN
# 3         01/23/2010 11:15:53 PM        01 BRONX  2.022690e+09     BRONX
# 4         02/10/2010 11:51:00 AM       12 QUEENS  4.120380e+09    QUEENS
#
#    X Coordinate (State Plane) Open Data Channel Type Park Facility Name  \
# 0                   1000663.0                  PHONE        Unspecified
# 1                   1052873.0                  PHONE        Unspecified
# 2                    990769.0                  PHONE     School - PS 77
# 3                   1007114.0                  PHONE        Unspecified
# 4                   1040656.0                  PHONE        Unspecified
#
#   Park Borough Vehicle Type Taxi Company Borough Taxi Pick Up Location  \
# 0     BROOKLYN          NaN                  NaN                   NaN
# 1       QUEENS          NaN                  NaN                   NaN
# 2     BROOKLYN          NaN                  NaN                   NaN
# 3        BRONX          NaN                  NaN                   NaN
# 4       QUEENS          NaN                  NaN                   NaN
#
#   Bridge Highway Name Bridge Highway Direction Road Ramp  \
# 0                 NaN                      NaN       NaN
# 1                 NaN                      NaN       NaN
# 2                 NaN                      NaN       NaN
# 3                 NaN                      NaN       NaN
# 4                 NaN                      NaN       NaN
#
#   Bridge Highway Segment Request_Closing_Time    year
# 0                    NaN      0 days 00:27:04  2010.0
# 1                    NaN      0 days 00:59:48  2010.0
# 2                    NaN     94 days 16:47:26  2010.0
# 3                    NaN      0 days 00:20:09  2010.0
# 4                    NaN     17 days 23:55:13  2010.0

# %%
sns.countplot(dataset['year'],hue='Borough',data=dataset)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
dataset['Location Type'].value_counts()
# Out:
# RESIDENTIAL BUILDING             5099
# Street                           1108
# Residential Building/House        828
# Street/Sidewalk                   615
# Sidewalk                          332
# Tenant Address                    175
# Property Address                  160
# Senior Address                    151
# Other                             150
# Club/Bar/Restaurant                97
# 3+ Family Apartment Building       46
# Restaurant/Bar/Deli/Bakery         44
# Store/Commercial                   42
# Park                               36
# 1-2 Family Dwelling                33
# 3+ Family Apt. Building            33
# Lot                                27
# Highway                            23
# Bus Stop Shelter                   20
# Other (Explain Below)              17
# School                             12
# Commercial Building                10
# 3+ Family Mixed Use Building        9
# Bridge                              8
# Park/Playground                     8
# Residential Building                8
# Address Unknown                     7
# Vacant Lot                          7
# Residential                         7
# House of Worship                    6
# Street and Sidewalk                 5
# Public/Unfenced Area                5
# Building (Non-Residential)          4
# Taxi                                3
# Vacant Building                     3
# Comercial                           2
# Ferry                               2
# Terminal                            2
# Recreation Center                   2
# 1-2 Family Mixed Use Building       2
# Street/Curbside                     2
# Service Provider                    1
# Soup Kitchen                        1
# Senior Center                       1
# Government Building                 1
# Public Garden                       1
# Tattoo Parlor                       1
# Beach                               1
# Residence                           1
# Roadway Tunnel                      1
# Food Cart Vendor                    1
# Parking Lot/Garage                  1
# Restaurant                          1
# Roadway                             1
# Name: Location Type, dtype: int64

# %%
#Display the complaint type and city together
dataset[['Complaint Type','City']].head()
# Out:
#         Complaint Type          City
# 0  Noise - Residential      BROOKLYN
# 1  Noise - Residential  FAR ROCKAWAY
# 2               Safety      BROOKLYN
# 3  Noise - Residential         BRONX
# 4        Unleashed Dog       JAMAICA

# %%
#Find the top 10 complaint types 
dataset['Complaint Type'].value_counts()[0:10,]
# Out:
# HEATING                 2138
# PLUMBING                 885
# Noise - Residential      818
# GENERAL CONSTRUCTION     769
# PAINT - PLASTER          564
# Damaged Tree             379
# NONCONST                 378
# Street Condition         319
# Blocked Driveway         275
# ELECTRIC                 267
# Name: Complaint Type, dtype: int64

# %%
#Plot a bar graph of count vs. complaint types
plot3=sns.countplot(dataset['Complaint Type'])
plot3.set_xticklabels(plot3.get_xticklabels(),rotation =90)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, 'Noise - Residential'),
#  Text(0, 0, 'Safety'),
#  Text(0, 0, 'Unleashed Dog'),
#  Text(0, 0, 'Noise - Street/Sidewalk'),
#  Text(0, 0, 'Traffic/Illegal Parking'),
#  Text(0, 0, 'Vending'),
#  Text(0, 0, 'Housing Options'),
#  Text(0, 0, 'Water System'),
#  Text(0, 0, 'Blocked Driveway'),
#  Text(0, 0, 'Noise - Vehicle'),
#  Text(0, 0, 'Sidewalk Condition'),
#  Text(0, 0, 'Root/Sewer/Sidewalk Condition'),
#  Text(0, 0, 'Broken Muni Meter'),
#  Text(0, 0, 'SCRIE'),
#  Text(0, 0, 'Broken Parking Meter'),
#  Text(0, 0, 'Derelict Vehicle'),
#  Text(0, 0, 'Rodent'),
#  Text(0, 0, 'Taxi Complaint'),
#  Text(0, 0, 'Drinking'),
#  Text(0, 0, 'Noise - Commercial'),
#  Text(0, 0, 'DOF Parking - Payment Issue'),
#  Text(0, 0, 'Indoor Air Quality'),
#  Text(0, 0, 'DOF Property - Request Copy'),
#  Text(0, 0, 'HPD Literature Request'),
#  Text(0, 0, 'Disorderly Youth'),
#  Text(0, 0, 'Consumer Complaint'),
#  Text(0, 0, 'Bus Stop Shelter Placement'),
#  Text(0, 0, 'Traffic Signal Condition'),
#  Text(0, 0, 'Maintenance or Facility'),
#  Text(0, 0, 'DCA / DOH New License Application Request'),
#  Text(0, 0, 'DHS Advantage - Tenant'),
#  Text(0, 0, 'Non-Emergency Police Matter'),
#  Text(0, 0, 'Noise - House of Worship'),
#  Text(0, 0, 'Street Condition'),
#  Text(0, 0, 'Damaged Tree'),
#  Text(0, 0, 'Food Poisoning'),
#  Text(0, 0, 'Curb Condition'),
#  Text(0, 0, 'Street Sign - Dangling'),
#  Text(0, 0, 'Smoking'),
#  Text(0, 0, 'DOF Parking - Request Copy'),
#  Text(0, 0, 'Eviction'),
#  Text(0, 0, 'Street Sign - Damaged'),
#  Text(0, 0, 'Bike/Roller/Skate Chronic'),
#  Text(0, 0, 'Literature Request'),
#  Text(0, 0, 'Highway Condition'),
#  Text(0, 0, 'Ferry Permit'),
#  Text(0, 0, 'Bridge Condition'),
#  Text(0, 0, 'Bottled Water'),
#  Text(0, 0, 'Found Property'),
#  Text(0, 0, 'Taxi Compliment'),
#  Text(0, 0, 'Food Establishment'),
#  Text(0, 0, 'Dead Tree'),
#  Text(0, 0, 'New Tree Request'),
#  Text(0, 0, 'Bus Stop Shelter Complaint'),
#  Text(0, 0, 'Street Sign - Missing'),
#  Text(0, 0, 'School Maintenance'),
#  Text(0, 0, 'NONCONST'),
#  Text(0, 0, 'ELECTRIC'),
#  Text(0, 0, 'HEATING'),
#  Text(0, 0, 'PLUMBING'),
#  Text(0, 0, 'PAINT - PLASTER'),
#  Text(0, 0, 'Lead'),
#  Text(0, 0, 'APPLIANCE'),
#  Text(0, 0, 'GENERAL CONSTRUCTION'),
#  Text(0, 0, 'Street Light Condition'),
#  Text(0, 0, 'Derelict Vehicles'),
#  Text(0, 0, 'DOF Property - Reduction Issue'),
#  Text(0, 0, 'Animal in a Park'),
#  Text(0, 0, 'Sewer'),
#  Text(0, 0, 'DOF Property - Owner Issue'),
#  Text(0, 0, 'Water Conservation'),
#  Text(0, 0, 'CONSTRUCTION'),
#  Text(0, 0, 'Noise'),
#  Text(0, 0, 'Asbestos'),
#  Text(0, 0, 'Hazardous Materials'),
#  Text(0, 0, 'Air Quality'),
#  Text(0, 0, 'Cranes and Derricks'),
#  Text(0, 0, 'General Construction/Plumbing'),
#  Text(0, 0, 'Elevator'),
#  Text(0, 0, 'Building/Use'),
#  Text(0, 0, 'BEST/Site Safety'),
#  Text(0, 0, 'Plumbing'),
#  Text(0, 0, 'Electrical'),
#  Text(0, 0, 'Special Projects Inspection Team (SPIT)'),
#  Text(0, 0, 'Boilers'),
#  Text(0, 0, 'Investigations and Discipline (IAD)'),
#  Text(0, 0, 'Graffiti'),
#  Text(0, 0, 'Unsanitary Animal Pvt Property'),
#  Text(0, 0, 'Noise - Park'),
#  Text(0, 0, 'Window Guard'),
#  Text(0, 0, 'Health'),
#  Text(0, 0, 'Illegal Animal Sold'),
#  Text(0, 0, 'Ferry Complaint'),
#  Text(0, 0, 'Sanitation Condition'),
#  Text(0, 0, 'DHS Advantage -Landlord/Broker'),
#  Text(0, 0, 'Illegal Tree Damage'),
#  Text(0, 0, 'For Hire Vehicle Complaint'),
#  Text(0, 0, 'Posting Advertisement'),
#  Text(0, 0, 'Unsanitary Pigeon Condition'),
#  Text(0, 0, 'Radioactive Material'),
#  Text(0, 0, 'Parent Leadership'),
#  Text(0, 0, 'Ferry Inquiry'),
#  Text(0, 0, 'HEAP Assistance'),
#  Text(0, 0, 'DOF Parking - Request Status'),
#  Text(0, 0, 'DOF Parking - DMV Clearance'),
#  Text(0, 0, 'DOF Property - Payment Issue'),
#  Text(0, 0, 'Missed Collection (All Materials)'),
#  Text(0, 0, 'Dirty Conditions'),
#  Text(0, 0, 'DOF Property - Property Value'),
#  Text(0, 0, 'Snow'),
#  Text(0, 0, 'Other Enforcement'),
#  Text(0, 0, 'Recycling Enforcement'),
#  Text(0, 0, 'Vacant Lot'),
#  Text(0, 0, 'Plant'),
#  Text(0, 0, 'Industrial Waste'),
#  Text(0, 0, 'Litter Basket / Request'),
#  Text(0, 0, 'Overflowing Litter Baskets'),
#  Text(0, 0, 'Non-Residential Heat'),
#  Text(0, 0, 'Overgrown Tree/Branches'),
#  Text(0, 0, 'Homeless Encampment'),
#  Text(0, 0, 'Highway Sign - Dangling'),
#  Text(0, 0, 'Weatherization'),
#  Text(0, 0, 'Urinating in Public'),
#  Text(0, 0, 'DHS Advantage - Third Party'),
#  Text(0, 0, 'DOF Property - City Rebate'),
#  Text(0, 0, 'Highway Sign - Missing'),
#  Text(0, 0, 'Tattooing'),
#  Text(0, 0, 'Public Payphone Complaint'),
#  Text(0, 0, 'OEM Literature Request'),
#  Text(0, 0, 'DOF Property - RPIE Issue'),
#  Text(0, 0, 'DOF Parking - Address Update'),
#  Text(0, 0, 'Elder Abuse'),
#  Text(0, 0, 'Home Repair'),
#  Text(0, 0, 'Utility Program'),
#  Text(0, 0, "Alzheimer's Care"),
#  Text(0, 0, 'Highway Sign - Damaged'),
#  Text(0, 0, 'Legal Services Provider Complaint'),
#  Text(0, 0, 'Mold'),
#  Text(0, 0, 'Municipal Parking Facility'),
#  Text(0, 0, 'Senior Center Complaint'),
#  Text(0, 0, 'City Vehicle Placard Complaint')]

# %%
#Display the major complaint types and their count
#top 5 complaint types
series=dataset['Complaint Type'].value_counts()[0:5,]
series.nlargest().index
# Out:
# Index(['HEATING', 'PLUMBING', 'Noise - Residential', 'GENERAL CONSTRUCTION',
#        'PAINT - PLASTER'],
#       dtype='object')

# %%
#graph
plot4=sns.barplot(x=series.nlargest().index,y=series.nlargest().values)
plot4.set_xticklabels(plot3.get_xticklabels(),rotation =90)
# Out:
# [Text(0, 0, 'Noise - Residential'),
#  Text(0, 0, 'Safety'),
#  Text(0, 0, 'Unleashed Dog'),
#  Text(0, 0, 'Noise - Street/Sidewalk'),
#  Text(0, 0, 'Traffic/Illegal Parking')]
